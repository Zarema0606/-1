# %%
# !pip install ipykernel

# %%
# !git clone https://github.com/lenarsaitov/cianparser.git
# Out:
# "git" �� ���� ����७��� ��� ���譥�
# ��������, �ᯮ��塞�� �ணࠬ��� ��� ������ 䠩���.

# %%
# !pip install cianparser
# Out:
# ...
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ------------- -------------------------- 1.3/3.8 MB 13.4 MB/s eta 0:00:01
#    ---------------------------------------- 3.8/3.8 MB 10.3 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 1.2/1.2 MB 10.5 MB/s eta 0:00:00
# ...

# %%
import cianparser

dolgop_parser = cianparser.CianParser(location="Долгопрудный")
data = dolgop_parser.get_flats(deal_type="sale", rooms=(1, 2, 3, 4, 5), with_saving_csv=True, additional_settings={"start_page":1, "end_page":50})
# Out:
#                               Preparing to collect information from pages..
# The absolute path to the file:
# d:\parsing_2\cianparser\cian_flat_sale_1_50_dolgoprudnyj_22_Oct_2024_14_24_07_228499.csv
#
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=4738&deal_type=sale&offer_type=flat&room1=1&room2=1&room3=1&room4=1&room5=1

# %%
# !pip install pandas

# %%
import cianparser
import pandas as pd
import time

kolomna = cianparser.CianParser(location='Коломна')

data = []
for i in range(1, 30):
    a = kolomna.get_flats(deal_type='sale', rooms=(1), additional_settings={'start_page': i, 'end_page':i} )
    data.extend(a)
    time.sleep(10)

exel_export = pd.DataFrame(data)
columns = ['author', 'author_type', 'location', 'deal_type', 'accommodation_type', 'floors_count', 'rooms_count', 'total_meters', 'price', 'district', 'street', 'house_number', 'underground', 'residential_complex']
selected_columns = exel_export[columns]
selected_columns.to_csv('cian_parsing.csv', mode='a', header=False, index=False)
# Out:
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=4809&deal_type=sale&offer_type=flat&room1=1
#
# ...
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 15 729 624 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=2&with_neighbors=0&region=4809&deal_type=sale&offer_type=flat&room1=1
#
# ...
#  1 | 2 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 21 511 749 rub
#
# ...
